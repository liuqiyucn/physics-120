# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import signal

# %% [markdown]
# ## 2-1

# %% [markdown]
# ## 2-2
# worst-case impedance?

# %% [markdown]
# ## 2-3
# input impedance at DC? <br>
# measurements

# %% [markdown]
# ## 2-4
#
# f_3db measurement experimentally <br>
# analytic function at high and low frequency

# %%
data = pd.read_csv("lab2 - Sheet1.csv")
y = data[["phase shift(degree)", "amplitude(v)"]].to_numpy()
phase = y[:,0]
amplitude = y[:,1]
print(amplitude)
x = np.logspace(np.log10(0.1*1125.35),np.log10(10*1125.35,), num=20)

fig, ax = plt.subplots(2, figsize = (5, 10))

#ax[0].semilogx(x, np.log10(amplitude/20.8)) # log-log
ax[0].scatter(x, np.log10(amplitude/20.8), s=60, alpha=0.7, edgecolors="k")
ax[0].set_xscale("log")
ax[0].set_title("Magnitude plot")
ax[0].set_xlabel("Frequency (Hz)", fontsize = 8)
ax[0].set_ylabel("Magnitude (logV)", fontsize = 8)
ax[1].semilogx(x, phase) # linear-log
ax[1].set_title("Phase plot")
ax[1].set_xlabel("Frequency (Hz)", fontsize = 8)
ax[1].set_ylabel("Phase (degree)", fontsize = 8)

plt.show()
print(1/(15*10**3 * 0.01*10**-6))

capacitor = 9.866*10**-9
resistor = 14.711 * 10 ** 3
print(1/(2*np.pi*capacitor*resistor))
print((15.2/20.6)/(1/np.sqrt(2)))
# Out:
# [20.8  20.8  20.8  20.6  20.2  19.8  19.2  18.4  17.2  15.8  14.   12.4
#  10.4   8.8   7.2   6.    4.32  3.4   2.7   2.2 ]
# 6666.666666666667
# 1096.5711735122666
# 1.0434973858286913

# %% [markdown]
# ## 2-5
#
# calculation of Bode plot and phase plot?

# %%
y = data[["phase shift", "amp"]].to_numpy()
phase = y[:,0]
amplitude = y[:,1]

fig, ax = plt.subplots(2, figsize = (5, 10))

ax[0].semilogx(x, np.log10(amplitude)) # log-log
ax[0].set_title("Magnitude plot")
ax[0].set_xlabel("Frequency (Hz)", fontsize = 8)
ax[0].set_ylabel("Magnitude (logV)", fontsize = 8)
ax[1].semilogx(x, phase) # linear-log
ax[1].set_title("Phase plot")
ax[1].set_xlabel("Frequency (Hz)", fontsize = 8)
ax[1].set_ylabel("Phase (degree)", fontsize = 8)

plt.show()

# %% [markdown]
# ## 2-6
#
# what is the filter attenuation? (amplitude grows llinearly with frequency below f_3db)

# %% [markdown]
# ## 2-7
#
# why filtering work?
